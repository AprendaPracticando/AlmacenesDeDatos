# %% [markdown]
# <a href="https://colab.research.google.com/github/AprendaPracticando/AlmacenesDeDatos/blob/main/ADV02_extract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 02 Extract usando pandas
#
# ---

# %%
# Importando la librería de pandas

import pandas as pd

# %%
# Referencia a archivo CSV en línea

url='https://raw.githubusercontent.com/AprendaPracticando/AlmacenesDeDatos/main/personas_titanic.csv'

# %%
# Carga de datos a un DataFrame

df=pd.read_csv(url)

# %%
# Verificando que los datos se han cargado

df
# Out:
#       id_persona  clave_sobrevivencia                                 nombre  \
# 0          10000                  0.0                 Andrews, Mr. Thomas Jr
# 1          10001                  0.0  Chisholm, Mr. Roderick Robert Crispin
# 2          10002                  0.0                       Fry, Mr. Richard
# 3          10003                  0.0                  Harrison, Mr. William
# 4          10004                  1.0                Ismay, Mr. Joseph Bruce
# ...          ...                  ...                                    ...
# 1305       11305                  0.0         Sage, Mrs. John (Annie Bullen)
# 1306       11306                  0.0                     Storey, Mr. Thomas
# 1307       11307                  0.0                    Baumann, Mr. John D
# 1308       11308                  NaN           Blackwell, Mr. Stephen Weart
# 1309       11309                  0.0               Baxter, Mr. Quigg Edmond
#
# ...
